# %%
import pandas as pd
import numpy as np
import ppscore as pps

path = r"C:\Users\Roman\Documents\CleanData\NormByWell"

df = pd.read_csv(r"C:\Users\Roman\Documents\CleanData\NormByWell\tubesProfiles.csv").drop(columns=['Unnamed: 0', 'Row','Column','PlateName','Nucleus Width [µm] (2)'])
df.rename(columns={'Compound':'y'}, inplace=True)

# %%
ppscores = pps.predictors(df, "y")
ppscores.head(20)
# Out:
#                                                     x  y   ppscore  \
# 0         Cell 488 Threshold Compactness 50% SER-Hole  y  0.197921
# 1                                  Nucleus Width [µm]  y  0.196459
# 2         Cell 488 Threshold Compactness 40% SER-Hole  y  0.181294
# 3        Cell Mito Threshold Compactness 50% SER-Hole  y  0.179839
# 4         Cell 488 Threshold Compactness 30% SER-Hole  y  0.175212
# 5        Cell Mito Threshold Compactness 60% SER-Hole  y  0.174113
# 6    Nucleus 33342 Threshold Compactness 40% SER-Hole  y  0.171281
# 7         Cell 568 Threshold Compactness 50% SER-Hole  y  0.169570
# 8    Nucleus 33342 Threshold Compactness 30% SER-Hole  y  0.168557
# 9       Cell 488 Threshold Compactness 60% SER-Valley  y  0.167489
# 10        Cell 488 Threshold Compactness 60% SER-Hole  y  0.167012
# 11      Cell 488 Threshold Compactness 60% SER-Saddle  y  0.160832
# 12        Cell 568 Threshold Compactness 40% SER-Spot  y  0.160227
# 13        Cell 488 Threshold Compactness 60% SER-Dark  y  0.159956
# 14        Cell 568 Threshold Compactness 40% SER-Hole  y  0.159593
# 15        Cell 568 Threshold Compactness 60% SER-Dark  y  0.159446
# 16        Cell 568 Threshold Compactness 60% SER-Hole  y  0.158359
# 17      Cell 568 Threshold Compactness 60% SER-Bright  y  0.156604
# 18  Nucleus 33342 Threshold Compactness 60% SER-Ridge  y  0.154596
# 19        Cell 568 Threshold Compactness 50% SER-Spot  y  0.151984
#
#               case  is_valid_score       metric  baseline_score  model_score  \
# 0   classification            True  weighted F1        0.050452     0.238388
# 1   classification            True  weighted F1        0.050452     0.236999
# 2   classification            True  weighted F1        0.050452     0.222600
# 3   classification            True  weighted F1        0.050452     0.221218
# 4   classification            True  weighted F1        0.050452     0.216824
# 5   classification            True  weighted F1        0.050452     0.215781
# 6   classification            True  weighted F1        0.050452     0.213092
# 7   classification            True  weighted F1        0.050452     0.211467
# 8   classification            True  weighted F1        0.050452     0.210505
# 9   classification            True  weighted F1        0.050452     0.209491
# 10  classification            True  weighted F1        0.050452     0.209038
# 11  classification            True  weighted F1        0.050452     0.203170
# 12  classification            True  weighted F1        0.050452     0.202595
# 13  classification            True  weighted F1        0.050452     0.202338
# 14  classification            True  weighted F1        0.050452     0.201993
# 15  classification            True  weighted F1        0.050452     0.201854
# 16  classification            True  weighted F1        0.050452     0.200822
# 17  classification            True  weighted F1        0.050452     0.199155
# 18  classification            True  weighted F1        0.050452     0.197249
# 19  classification            True  weighted F1        0.050452     0.194768
#
#                        model
# 0   DecisionTreeClassifier()
# 1   DecisionTreeClassifier()
# 2   DecisionTreeClassifier()
# 3   DecisionTreeClassifier()
# 4   DecisionTreeClassifier()
# 5   DecisionTreeClassifier()
# 6   DecisionTreeClassifier()
# 7   DecisionTreeClassifier()
# 8   DecisionTreeClassifier()
# 9   DecisionTreeClassifier()
# 10  DecisionTreeClassifier()
# 11  DecisionTreeClassifier()
# 12  DecisionTreeClassifier()
# 13  DecisionTreeClassifier()
# 14  DecisionTreeClassifier()
# 15  DecisionTreeClassifier()
# 16  DecisionTreeClassifier()
# 17  DecisionTreeClassifier()
# 18  DecisionTreeClassifier()
# 19  DecisionTreeClassifier()

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix

# filter out features with low ppscore but keep 'y' column
features_to_keep = ppscores.loc[ppscores['ppscore'] > 0.05, 'x'].append(pd.Series('y'))
df_filt = df[features_to_keep]

X = df_filt.drop(columns=['y','Concentration'])
y = df_filt['y']
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=42, stratify=y, test_size=0.2)

rf = RandomForestClassifier(n_estimators=500, random_state=42, max_depth=5)
rf.fit(X_train, y_train)

y_pred = pd.Series(rf.predict(X_test))
y_pred_proba = rf.predict_proba(X_test)


print('Accuracy of random forest classifier on test set: {:.2f}'.format(rf.score(X_test, y_test)))
print('ROC AUC score of random forest classifier on test set: {:.2f}'.format(roc_auc_score(y_test, y_pred_proba, multi_class='ovr')))

conf_matrix = confusion_matrix(y_test, y_pred)


# feature importance
feature_importance = pd.DataFrame({'feature': X_train.columns, 'importance': rf.feature_importances_})
feature_importance.sort_values(by='importance', ascending=False, inplace=True)
feature_importance.reset_index(drop=True, inplace=True)
feature_importance
# Out:
# C:\Users\Roman\AppData\Local\Temp\ipykernel_31168\355047523.py:7: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   features_to_keep = ppscores.loc[ppscores['ppscore'] > 0.05, 'x'].append(pd.Series('y'))
# Accuracy of random forest classifier on test set: 0.37
# ROC AUC score of random forest classifier on test set: 0.88
#                                               feature  importance
# 0                          Cytoplasm 488 Profile 4/5     0.045289
# 1                    Intensity Nucleus Alexa 555 Mean    0.043754
# 2                     Nucleus Alexa 488 SER Hole 0 px    0.036987
# 3                          Cytoplasm 488 Profile 5/5     0.032426
# 4                Intensity Ring Region Alexa 488 Mean    0.032341
# ..                                                ...         ...
# 124       Cell 568 Threshold Compactness 60% SER-Edge    0.001261
# 125    Cell Mito Threshold Compactness 50% SER-Saddle    0.001241
# 126  Nucleus 33342 Threshold Compactness 40% SER-Dark    0.001127
# 127    Cell Mito Threshold Compactness 40% SER-Saddle    0.001014
# 128      Cell 568 Threshold Compactness 40% SER-Ridge    0.000945
#
# [129 rows x 2 columns]

# %%
from sklearn.inspection import permutation_importance

result = permutation_importance(rf, X_train, y_train, n_repeats=10, random_state=42, n_jobs=2)
# Out:
# {'importances_mean': array([ 1.49253731e-03,  2.46268657e-03,  1.86567164e-03,  2.42537313e-03,
#          2.16417910e-03,  6.23134328e-03,  1.06343284e-02,  4.10447761e-03,
#          2.98507463e-03, -7.46268657e-05,  5.33582090e-03,  5.41044776e-03,
#          1.71641791e-03,  1.79104478e-03,  1.11940299e-03,  4.85074627e-04,
#          4.21641791e-03,  1.34328358e-03,  5.22388060e-04,  1.26865672e-03,
#          2.83582090e-03,  1.28358209e-02,  7.83582090e-03,  1.26865672e-03,
#          1.60447761e-03,  1.41791045e-03,  1.97761194e-03,  1.75373134e-03,
#          4.47761194e-04,  1.41791045e-03,  1.64179104e-03,  6.64179104e-03,
#          7.42537313e-03,  7.01492537e-03,  1.23134328e-03,  1.41791045e-03,
#          2.91044776e-03,  5.59701493e-03,  3.54477612e-03,  2.91044776e-03,
#          2.42537313e-03,  1.60447761e-03,  2.94776119e-03,  3.61940299e-03,
#          2.20149254e-03,  0.00000000e+00,  1.11940299e-03,  1.82835821e-03,
#          5.97014925e-04,  8.95522388e-04,  4.10447761e-04,  1.64179104e-03,
#          2.38805970e-03,  1.08208955e-03,  1.08208955e-03,  4.02985075e-03,
#          1.19402985e-03,  6.34328358e-03,  1.56716418e-03,  3.99253731e-03,
#          3.99253731e-03,  6.34328358e-04,  2.27611940e-03,  1.67910448e-03,
#          1.71641791e-03,  1.41791045e-03,  1.56716418e-03,  2.08955224e-03,
#          5.33582090e-03,  1.04477612e-03,  6.15671642e-03,  6.60447761e-03,
#          3.35820896e-03,  2.42537313e-03,  1.52985075e-03,  2.27611940e-03,
#          7.38805970e-03,  3.43283582e-03,  1.19402985e-03,  1.11940299e-03,
#          1.45522388e-03,  7.46268657e-04,  2.08955224e-03,  5.41044776e-03,
#          6.71641791e-04,  7.08955224e-04,  1.71641791e-03,  1.86567164e-04,
#          1.41791045e-03,  3.88059701e-03,  1.19402985e-03,  8.95522388e-04,
#          2.79850746e-03,  1.23134328e-03, -3.73134328e-05,  1.80597015e-02,
#          3.50746269e-03,  4.10447761e-04,  1.11940299e-02,  7.12686567e-03,
#          2.60074627e-02,  1.97761194e-03,  1.45522388e-03, -1.00746269e-03,
#          6.41791045e-03,  4.25373134e-03,  2.60447761e-02,  1.82835821e-03,
#          3.52611940e-02,  8.50746269e-03,  5.52238806e-03, -7.46268657e-05,
#          1.13059701e-02,  1.58582090e-02,  3.13432836e-03,  1.67910448e-03,
#          2.00000000e-02,  5.59701493e-04,  5.70895522e-03,  1.19402985e-03,
#          1.35820896e-02,  1.72761194e-02,  4.40298507e-03,  2.98507463e-04,
#          1.45522388e-03,  3.95522388e-03,  5.18656716e-03,  3.76865672e-03,
#          3.91791045e-03]),
#  'importances_std': array([0.00117995, 0.00065058, 0.00091399, 0.00153167, 0.00049502,
#         0.00131447, 0.00166244, 0.00124875, 0.0008175 , 0.00046604,
#         0.00134587, 0.00227122, 0.00094691, 0.00046604, 0.00078269,
#         0.00070896, 0.00177425, 0.00050614, 0.00073119, 0.00065058,
#         0.00078624, 0.00276824, 0.00178169, 0.00034198, 0.00078358,
#         0.0006633 , 0.00110752, 0.00072833, 0.00076105, 0.00131182,
#         0.00088614, 0.0022807 , 0.00157823, 0.00102595, 0.00088379,
#         0.00068397, 0.00086387, 0.00140608, 0.0004793 , 0.00064196,
#         0.00091779, 0.00066853, 0.00063433, 0.001493  , 0.00079066,
#         0.00050061, 0.00055345, 0.00071677, 0.00038052, 0.00050614,
#         0.0005888 , 0.00055846, 0.00076833, 0.00038956, 0.00045547,
#         0.00068397, 0.0006199 , 0.00117995, 0.00074253, 0.0009447 ,
#         0.00176639, 0.00033582, 0.00061199, 0.00044931, 0.00078624,
#         0.00074253, 0.00076105, 0.00050614, 0.00132502, 0.00086387,
#         0.00093284, 0.0016183 , 0.00098722, 0.00129527, 0.00141053,
#         0.00053943, 0.00099844, 0.00059701, 0.00054839, 0.00062437,
#         0.0020468 , 0.00104211, 0.00113423, 0.00071287, 0.00072353,
#         0.00045547, 0.00071189, 0.00087109, 0.00074253, 0.00088614,
#         0.00064196, 0.00029851, 0.00117107, 0.00044307, 0.00035201,
#         0.00369836, 0.00120563, 0.00026119, 0.00205732, 0.00254416,
#         0.00367135, 0.00092985, 0.00061199, 0.001601  , 0.00068397,
#         0.00160231, 0.00251859, 0.00045547, 0.00281834, 0.0026374 ,
#         0.00156361, 0.00049502, 0.00217605, 0.00194782, 0.00067164,
#         0.00062992, 0.00269174, 0.00058405, 0.00196773, 0.00049502,
#         0.00193311, 0.00254197, 0.0006199 , 0.00046604, 0.00053943,
#         0.0014944 , 0.00121998, 0.00119694, 0.00153167]),
#  'importances': array([[0.00373134, 0.00149254, 0.00037313, ..., 0.00037313, 0.00149254,
#          0.00149254],
#         [0.00186567, 0.00298507, 0.00298507, ..., 0.00149254, 0.00261194,
#          0.00335821],
#         [0.00186567, 0.0011194 , 0.00223881, ..., 0.0011194 , 0.00149254,
#          0.00186567],
#         ...,
#         [0.00485075, 0.00708955, 0.00485075, ..., 0.00447761, 0.00634328,
#          0.00708955],
#         [0.00559701, 0.00559701, 0.00373134, ..., 0.00298507, 0.00447761,
#          0.00149254],
#         [0.00559701, 0.00485075, 0.00559701, ..., 0.00149254, 0.00447761,
#          0.00261194]])}

# %%
result.importances_mean
rf.
# Out:
# array([ 1.49253731e-03,  2.46268657e-03,  1.86567164e-03,  2.42537313e-03,
#         2.16417910e-03,  6.23134328e-03,  1.06343284e-02,  4.10447761e-03,
#         2.98507463e-03, -7.46268657e-05,  5.33582090e-03,  5.41044776e-03,
#         1.71641791e-03,  1.79104478e-03,  1.11940299e-03,  4.85074627e-04,
#         4.21641791e-03,  1.34328358e-03,  5.22388060e-04,  1.26865672e-03,
#         2.83582090e-03,  1.28358209e-02,  7.83582090e-03,  1.26865672e-03,
#         1.60447761e-03,  1.41791045e-03,  1.97761194e-03,  1.75373134e-03,
#         4.47761194e-04,  1.41791045e-03,  1.64179104e-03,  6.64179104e-03,
#         7.42537313e-03,  7.01492537e-03,  1.23134328e-03,  1.41791045e-03,
#         2.91044776e-03,  5.59701493e-03,  3.54477612e-03,  2.91044776e-03,
#         2.42537313e-03,  1.60447761e-03,  2.94776119e-03,  3.61940299e-03,
#         2.20149254e-03,  0.00000000e+00,  1.11940299e-03,  1.82835821e-03,
#         5.97014925e-04,  8.95522388e-04,  4.10447761e-04,  1.64179104e-03,
#         2.38805970e-03,  1.08208955e-03,  1.08208955e-03,  4.02985075e-03,
#         1.19402985e-03,  6.34328358e-03,  1.56716418e-03,  3.99253731e-03,
#         3.99253731e-03,  6.34328358e-04,  2.27611940e-03,  1.67910448e-03,
#         1.71641791e-03,  1.41791045e-03,  1.56716418e-03,  2.08955224e-03,
#         5.33582090e-03,  1.04477612e-03,  6.15671642e-03,  6.60447761e-03,
#         3.35820896e-03,  2.42537313e-03,  1.52985075e-03,  2.27611940e-03,
#         7.38805970e-03,  3.43283582e-03,  1.19402985e-03,  1.11940299e-03,
#         1.45522388e-03,  7.46268657e-04,  2.08955224e-03,  5.41044776e-03,
#         6.71641791e-04,  7.08955224e-04,  1.71641791e-03,  1.86567164e-04,
#         1.41791045e-03,  3.88059701e-03,  1.19402985e-03,  8.95522388e-04,
#         2.79850746e-03,  1.23134328e-03, -3.73134328e-05,  1.80597015e-02,
#         3.50746269e-03,  4.10447761e-04,  1.11940299e-02,  7.12686567e-03,
#         2.60074627e-02,  1.97761194e-03,  1.45522388e-03, -1.00746269e-03,
#         6.41791045e-03,  4.25373134e-03,  2.60447761e-02,  1.82835821e-03,
#         3.52611940e-02,  8.50746269e-03,  5.52238806e-03, -7.46268657e-05,
#         1.13059701e-02,  1.58582090e-02,  3.13432836e-03,  1.67910448e-03,
#         2.00000000e-02,  5.59701493e-04,  5.70895522e-03,  1.19402985e-03,
#         1.35820896e-02,  1.72761194e-02,  4.40298507e-03,  2.98507463e-04,
#         1.45522388e-03,  3.95522388e-03,  5.18656716e-03,  3.76865672e-03,
#         3.91791045e-03])
